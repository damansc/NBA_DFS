# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np
import os

# %%
def get_boxscore_links(year='2020'):

    """
    retrieves all links to every single available box score.
    It seems that bball reference lags behind a bit.
    I ran today (1/6/20) and only through 1/4/20 is up.
    """

    months = ['october', 'november', 'december', 'january', 'february', 'march', 'april']
    root = 'https://www.basketball-reference.com'
    boxscore_links = []
    for month in months:
        source = requests.get(f'https://www.basketball-reference.com/leagues/NBA_{year}_games-{month}.html')
        soup = BeautifulSoup(source.content, 'html.parser')
        a_soup = soup.findAll('a')
        a_tags = []

        for a in a_soup:
            if (a.get('href')[0:4] == '/box') & (len(a.get('href')) == 28):
                a_tags.append(a.get('href'))

        for x in a_tags:
            boxscore_links.append(root + x)

    return boxscore_links

# %%
box_links = get_boxscore_links()
source = requests.get(box_links[100])
soup = BeautifulSoup(source.content, 'html.parser')
table = soup.find('table')
    
table_list = []   
for table in soup.findAll('table'):
    key = table.get_text()
    table_list.append(key)

thead_list = []
for thead in soup.findAll('thead'):
    key = thead.get_text()
    thead_list.append(key)

    
# gets the th values for each table head
#for theads in soup.findAll('thead'):
#    for th in theads.findAll('th'):
#        print(th.get_text())
# Out:
# Orlando Magic (2-5) Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
#
# Nikola Vučević33:39415.26703.000221.00039122021110-16
# Evan Fournier32:5507.00002.000441.000055120324-13
# Jonathan Isaac31:1059.55614.250221.00046100031213-14
# Aaron Gordon28:34613.46203.00034.7502573002515-4
# Markelle Fultz23:53510.50012.500221.0002134102313-14
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# D.J. Augustin27:00310.30004.00078.8750112000113+8
# Al-Farouq Aminu25:5245.80000551.0002351202413+1
# Terrence Ross22:4625.40001.000221.000123201236+4
# Mo Bamba14:1138.37513.33302.000257002137+8
# Khem BirchDid Not Play
# Michael Carter-WilliamsDid Not Play
# Melvin FrazierDid Not Play
# Wesley IwunduDid Not Play
#
# Team Totals2403282.390322.1362731.8711637531558142494
